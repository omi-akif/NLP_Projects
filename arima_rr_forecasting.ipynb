# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# pd.options.plotting.backend = "plotly"

# %%
df = pd.read_csv(r'Data_2021_2022.csv')

# %%
df.columns
# Out:
# Index(['date_id', 'Knowledge Count', 'Chats', 'Sessions',
#        'Direct Live Agent Sessions', 'Resolved Sessions',
#        'Session Resolved Rate', 'Session No Answer Rate',
#        'Switch to Live Agent Rate', 'Session Rec Not Accepted Rate',
#        'Session Unsatisfied Rate', 'Click to Live Agent Sessions',
#        'Click to Live Agent Rate', 'Intention to Live Agent Sessions',
#        'Intention to Live Agent Rate'],
#       dtype='object')

# %%
df3 = df[['Knowledge Count', 'Chats', 'Sessions', 'Direct Live Agent Sessions', 'Resolved Sessions', 'Click to Live Agent Sessions', 'Intention to Live Agent Sessions']]

# %%
df3
# Out:
#     Knowledge Count   Chats Sessions Direct Live Agent Sessions  \
# 0                 2    6842     3033                        771
# 1                 2    7816     3307                        660
# 2                 2    8747     3631                        813
# 3                 2    8429     3498                        830
# 4                 2    8460     3559                        761
# ..              ...     ...      ...                        ...
# 633               6  30,916    8,513                        567
# 634               6  28,887    7,857                        566
# 635               6  28,879    7,973                        658
# 636               6  33,891    8,488                        498
# 637               6  24,650    6,554                        410
#
#     Resolved Sessions Click to Live Agent Sessions  \
# 0                1165                          647
# 1                1469                          664
# ...

# %%
df['date_id'] = pd.to_datetime(df['date_id'], format='%Y%m%d')

# %%
df2 = df.set_index('date_id')

# %%
df2 = df2.astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15708/3600536987.py in <module>
# ----> 1 df2 = df2.astype(float)
#
# c:\Users\Daraz\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# c:\Users\Daraz\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     420
#     421     def convert(
#
# ...

# %%
df2
# Out:
#            Knowledge Count  Chats  Sessions  Direct Live Agent Sessions  \
# date_id
# 2021-01-01               2   6842      3033                         771
# 2021-01-02               2   7816      3307                         660
# 2021-01-03               2   8747      3631                         813
# 2021-01-04               2   8429      3498                         830
# 2021-01-05               2   8460      3559                         761
# ...                    ...    ...       ...                         ...
# 2022-09-26               6  30916      8513                         567
# 2022-09-27               6  28887      7857                         566
# 2022-09-28               6  28879      7973                         658
# 2022-09-29               6  33891      8488                         498
# 2022-09-30               6  24650      6554                         410
#
#             Resolved Sessions  Session Resolved Rate  Session No Answer Rate  \
# date_id
# ...

# %%
pl = df2['Resolved Sessions'].plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15708/2903406872.py in <module>
# ----> 1 pl = df2['Resolved Sessions'].plot()
#       2 plt.show()
#
# c:\Users\Daraz\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# c:\Users\Daraz\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ...

# %%
for i in range(1, 50):
    print(df2['Sessions'].autocorr(i))
# Out:
# 0.8089436144567236
# 0.7248415262185868
# 0.6877301241716594
# 0.6570849719740154
# 0.6167003562984829
# 0.6096068972387916
# 0.6134838408935902
# 0.5665268061129021
# 0.5332846068218786
# 0.5258519685005845
# 0.4905644556894717
# 0.4564877740569667
# 0.45294294596390433
# 0.46366110859156673
# 0.42625745309389323
# 0.4024480265845103
# 0.3949727931853367
# 0.3864005843124625
# 0.38251150633898695
# 0.39075973351567456
# 0.4252613046463776
# 0.4048352659263516
# 0.401166456231446
# 0.4112438745278573
# 0.4188871406731472
# 0.4144581832376084
# 0.4303906701937675
# 0.4643771979632078
# 0.4351228119820811
# 0.4304904000819083
# 0.4865828683838339
# 0.44582770373520864
# 0.42855286132666437
# 0.43400722058650787
# 0.465813436278603
# 0.4185375848064521
# 0.38798218302219717
# 0.38426639487234543
# 0.37355287093101924
# 0.3618821750942111
# 0.36453948076276466
# 0.37307143372258766
# 0.3155922653354471
# 0.2989213235101806
# 0.2855387243505078
# 0.27356990365009587
# 0.2558477780690144
# ...

# %%
from statsmodels.tsa.arima_model import ARIMA
# Out:
# c:\Users\Daraz\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# c:\Users\Daraz\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,

# %%
model = ARIMA(df2.dropna(), order=(5,0,0))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15708/2421019340.py in <module>
# ----> 1 model = ARIMA(df2.dropna(), order=(5,0,0))
#
# c:\Users\Daraz\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py in __new__(cls, endog, order, exog, dates, freq, missing)
#    1066         p, d, q = order
#    1067         if d == 0:  # then we just use an ARMA model
# -> 1068             return ARMA(endog, (p, q), exog, dates, freq, missing)
#    1069         else:
#    1070             mod = super(ARIMA, cls).__new__(cls)
#
# c:\Users\Daraz\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py in __init__(self, endog, order, exog, dates, freq, missing)
#     471         import warnings
#     472         warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# --> 473         super(ARMA, self).__init__(endog, exog, dates, freq, missing=missing)
# ...
