# %%
from time import sleep
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver import ActionChains
from parsel import Selector
from json import dumps

# %%
driver = webdriver.Chrome('D:\Chrome_Driver\chromedriver.exe')
    #for bash terminal: /mnt/d/Chrome_Driver/chromedriver.exe
    #for cmd terminal: D:\Chrome_Driver\chromedriver.exe
driver.get('https://www.linkedin.com/login?trk=guest_homepage-basic_nav-header-signin')

# %%
#username authentication
username = driver.find_element_by_id('username')
username.send_keys('omiakif@gmail.com')
sleep(0.5)

#password authentication
password = driver.find_element_by_id('password')
password.send_keys('m911springfieldm911')
sleep(0.5)

#login
log_in_button = driver.find_element_by_xpath('//*[@type="submit"]')
log_in_button.click()
sleep(4)

# %%
driver.execute_script("window.open('https://www.linkedin.com/search/results/people/?origin=DISCOVER_FROM_SEARCH_HOME');")
sleep(3)

driver.close()
driver.switch_to.window(driver.window_handles[-1])

# %%
#all_filters = driver.find_element_by_xpath('//*[@id="ember272"]/span')
#all_filters = driver.find_element_by_link_text('All Filters')

search = driver.find_element_by_xpath('//*[@id="ember33"]/input')
search.send_keys('East West University')
search.send_keys(Keys.ENTER)

# %%
    driver.execute_script("window.scrollTo(0,557);")
    sleep(0.5)
    driver.execute_script("window.scrollTo(557,1114);")
    sleep(0.5)
    driver.execute_script("window.scrollTo(1114,1671);")
    sleep(0.5)
    driver.execute_script("window.scrollTo(1671,2229);")
    sleep(0.5)
    #linkedin_urls = driver.find_elements_by_class_name('name actor-name')
    linkedin_urls = driver.find_elements_by_css_selector('span.name.actor-name')
    current_pos = driver.find_elements_by_css_selector('p.search-result__snippets.mt2.t-12.t-black--light.t-normal')
    #//*[@id="ember1835"]/div/div[2]/p[1]/span


    #Actions myAction = new Actions(driver); 
    #myAction.contextClick(driver.findElement(By.xpath("//ul/li[1]/a/img"))).build().perform();
    #myAction.sendKeys(Keys.ARROW_DOWN).build().perform();
    #myAction.sendKeys(Keys.ARROW_DOWN).build().perform();
    #myAction.sendKeys(Keys.ARROW_DOWN).build().perform();
    #myAction.sendKeys(Keys.ARROW_DOWN).build().perform();
    #myAction.sendKeys(Keys.ENTER).build().perform();

    #if linkedin_urls[0] == linkedin_urls[-1]:
    #    break
    #el3 = driver.find_element_by_css_selector(".action-btn.cancel.alert-display")
    ##ember388 > span > span > span.name.actor-name
    
    name_1 = [url.text for url in linkedin_urls]
    current_pos_txt = [ul.text for ul in current_pos]

    print(name_1)
    #f = open('output.html', 'w')
    #driver.page_source = f
# Out:
# ['Noorjahan Shaily', 'Khandaker Razzak', 'Kazi Md Farhad Mahmud', 'Farhana Rahman', 'Razwan Ahmed Tanvir', 'Farjana Sharmin Swarna', 'Istiaq Jahan Shuvo', 'Shantanu Rahut', 'Alamin Sheikh', 'Afroja Mukta']

# %%
linkedin_urls
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8395e8811d76a31f7d494c56f3c28659", element="0.639072678325898-2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8395e8811d76a31f7d494c56f3c28659", element="0.639072678325898-3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8395e8811d76a31f7d494c56f3c28659", element="0.639072678325898-4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8395e8811d76a31f7d494c56f3c28659", element="0.639072678325898-5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8395e8811d76a31f7d494c56f3c28659", element="0.639072678325898-6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8395e8811d76a31f7d494c56f3c28659", element="0.639072678325898-7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8395e8811d76a31f7d494c56f3c28659", element="0.639072678325898-8")>,
# ...

# %%
name_1 = [url.text for url in linkedin_urls]

# %%
name_1
# Out:
# ['Noorjahan Shaily',
#  'Khandaker Razzak',
#  'Kazi Md Farhad Mahmud',
#  'Farhana Rahman',
#  'Razwan Ahmed Tanvir',
#  'Farjana Sharmin Swarna',
#  'Istiaq Jahan Shuvo',
#  'Shantanu Rahut',
#  'Alamin Sheikh',
#  'Afroja Mukta']

# %%
linkedin_urls[0]
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="8395e8811d76a31f7d494c56f3c28659", element="0.639072678325898-2")>

# %%
linkedin_urls[0].get_attribute('innerHTML')
# Out:
# 'Noorjahan Shaily'

# %%
linkedin_urls[0].get_attribute('outerHTML')
# Out:
# '<span class="name actor-name">Noorjahan Shaily</span>'

# %%
driver.get('https://www.google.com')

# %%
driver.get('https://www.linkedin.com/search/results/people/?keywords=east%20west%20university&origin=GLOBAL_SEARCH_HEADER')

# %%
urls = driver.find_element_by_css_selector('a.search-result__result-link.ember-view')

# %%
urls
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="8395e8811d76a31f7d494c56f3c28659", element="0.14607590947661508-1")>

# %%
urls.get_attribute('innerHTML')
# Out:
# '      <figure class="search-result__image">\n          <div id="ember65" class="ivm-image-view-model ember-view">  <div id="ember66" class="display-flex ivm-view-attr__img-wrapper ivm-view-attr__img-wrapper--use-img-tag ember-view"><!---->    <div id="ember67" class="presence-entity presence-entity--size-4 ember-view"><img class="lazy-image ivm-view-attr__img--centered  EntityPhoto-circle-4 presence-entity__image EntityPhoto-circle-4 loaded" alt="Noorjahan Shaily" src="https://media.licdn.com/dms/image/C5103AQHdK-WWfOsORQ/profile-displayphoto-shrink_800_800/0?e=1565222400&amp;v=beta&amp;t=sXhMFr-eueFSVd5BFzIwbPenOB9-uLDl4zs-qdCao4c">\n\n<div id="ember68" class=" presence-entity__indicator presence-entity__indicator--size-4 presence-indicator presence-indicator--is-reachable presence-indicator--size-4 ember-view">\n<span class="visually-hidden">\n    Status is reachable\n</span>\n</div>\n</div>\n</div>\n</div>\n      </figure>\n'

# %%
urls.get_attribute('outerHTML')
# Out:
# '<a data-control-id="1yEqrqmTQbaxY/rB/CGJKw==" data-control-name="search_srp_result" href="/in/noorjahan-shaily-a27a22127/" id="ember64" class="search-result__result-link ember-view">      <figure class="search-result__image">\n          <div id="ember65" class="ivm-image-view-model ember-view">  <div id="ember66" class="display-flex ivm-view-attr__img-wrapper ivm-view-attr__img-wrapper--use-img-tag ember-view"><!---->    <div id="ember67" class="presence-entity presence-entity--size-4 ember-view"><img class="lazy-image ivm-view-attr__img--centered  EntityPhoto-circle-4 presence-entity__image EntityPhoto-circle-4 loaded" alt="Noorjahan Shaily" src="https://media.licdn.com/dms/image/C5103AQHdK-WWfOsORQ/profile-displayphoto-shrink_800_800/0?e=1565222400&amp;v=beta&amp;t=sXhMFr-eueFSVd5BFzIwbPenOB9-uLDl4zs-qdCao4c">\n\n<div id="ember68" class=" presence-entity__indicator presence-entity__indicator--size-4 presence-indicator presence-indicator--is-reachable presence-indicator--size-4 emb
# ...

# %%
linkedin_urls[1]
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="8395e8811d76a31f7d494c56f3c28659", element="0.639072678325898-3")>

# %%
urls = driver.find_element_by_css_selector('a.search-result__result-link.ember-view')

# %%
urls
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="8395e8811d76a31f7d494c56f3c28659", element="0.14607590947661508-1")>

# %%
urls.get_attribute('innerHTML')
# Out:
# '      <figure class="search-result__image">\n          <div id="ember65" class="ivm-image-view-model ember-view">  <div id="ember66" class="display-flex ivm-view-attr__img-wrapper ivm-view-attr__img-wrapper--use-img-tag ember-view"><!---->    <div id="ember67" class="presence-entity presence-entity--size-4 ember-view"><img class="lazy-image ivm-view-attr__img--centered  EntityPhoto-circle-4 presence-entity__image EntityPhoto-circle-4 loaded" alt="Noorjahan Shaily" src="https://media.licdn.com/dms/image/C5103AQHdK-WWfOsORQ/profile-displayphoto-shrink_800_800/0?e=1565222400&amp;v=beta&amp;t=sXhMFr-eueFSVd5BFzIwbPenOB9-uLDl4zs-qdCao4c">\n\n<div id="ember68" class=" presence-entity__indicator presence-entity__indicator--size-4 presence-indicator presence-indicator--is-reachable presence-indicator--size-4 ember-view">\n<span class="visually-hidden">\n    Status is reachable\n</span>\n</div>\n</div>\n</div>\n</div>\n      </figure>\n'

# %%
urls.get_attribute('outerHTML')
# Out:
# '<a data-control-id="1yEqrqmTQbaxY/rB/CGJKw==" data-control-name="search_srp_result" href="/in/noorjahan-shaily-a27a22127/" id="ember64" class="search-result__result-link ember-view">      <figure class="search-result__image">\n          <div id="ember65" class="ivm-image-view-model ember-view">  <div id="ember66" class="display-flex ivm-view-attr__img-wrapper ivm-view-attr__img-wrapper--use-img-tag ember-view"><!---->    <div id="ember67" class="presence-entity presence-entity--size-4 ember-view"><img class="lazy-image ivm-view-attr__img--centered  EntityPhoto-circle-4 presence-entity__image EntityPhoto-circle-4 loaded" alt="Noorjahan Shaily" src="https://media.licdn.com/dms/image/C5103AQHdK-WWfOsORQ/profile-displayphoto-shrink_800_800/0?e=1565222400&amp;v=beta&amp;t=sXhMFr-eueFSVd5BFzIwbPenOB9-uLDl4zs-qdCao4c">\n\n<div id="ember68" class=" presence-entity__indicator presence-entity__indicator--size-4 presence-indicator presence-indicator--is-reachable presence-indicator--size-4 emb
# ...

# %%
m = urls.get_attribute('outerHTML')

# %%
urls.text
# Out:
# 'Status is reachable'

# %%
urls
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="8395e8811d76a31f7d494c56f3c28659", element="0.14607590947661508-1")>

# %%
urls.get_attribute('outerHTML')
# Out:
# '<a data-control-id="1yEqrqmTQbaxY/rB/CGJKw==" data-control-name="search_srp_result" href="/in/noorjahan-shaily-a27a22127/" id="ember64" class="search-result__result-link ember-view">      <figure class="search-result__image">\n          <div id="ember65" class="ivm-image-view-model ember-view">  <div id="ember66" class="display-flex ivm-view-attr__img-wrapper ivm-view-attr__img-wrapper--use-img-tag ember-view"><!---->    <div id="ember67" class="presence-entity presence-entity--size-4 ember-view"><img class="lazy-image ivm-view-attr__img--centered  EntityPhoto-circle-4 presence-entity__image EntityPhoto-circle-4 loaded" alt="Noorjahan Shaily" src="https://media.licdn.com/dms/image/C5103AQHdK-WWfOsORQ/profile-displayphoto-shrink_800_800/0?e=1565222400&amp;v=beta&amp;t=sXhMFr-eueFSVd5BFzIwbPenOB9-uLDl4zs-qdCao4c">\n\n<div id="ember68" class=" presence-entity__indicator presence-entity__indicator--size-4 presence-indicator presence-indicator--is-reachable presence-indicator--size-4 emb
# ...

# %%
urls.get_attribute('href')
# Out:
# 'https://www.linkedin.com/in/noorjahan-shaily-a27a22127/'

# %%
ul = driver.find_element_by_css_selector('a.search-result__result-link.ember-view')

# %%
ul.get_attribute('href')
# Out:
# 'https://www.linkedin.com/in/noorjahan-shaily-a27a22127/'

# %%
c = ul.get_attribute('href')

# %%
driver.execute_script("window.open(arguments[0]);", c)

# %%
sel = Selector(text=driver.page_source)

# %%
driver.switch_to.window(driver.window_handles[-1])

# %%
sel = Selector(text=driver.page_source)

# %%
name_2 = sel.css('li.inline.t-24.t-black.t-normal.break-words')

# %%
name_2
# Out:
# [<Selector xpath="descendant-or-self::li[@class and contains(concat(' ', normalize-space(@class), ' '), ' inline ') and (@class and contains(concat(' ', normalize-space(@class), ' '), ' t-24 ')) and (@class and contains(concat(' ', normalize-space(@class), ' '), ' t-black ')) and (@class and contains(concat(' ', normalize-space(@class), ' '), ' t-normal ')) and (@class and contains(concat(' ', normalize-space(@class), ' '), ' break-words '))]" data='<li class="inline t-24 t-black t-normal '>]

# %%
name_2 = sel.css('li.inline.t-24.t-black.t-normal.break-words').extract_first()

# %%
name_2
# Out:
# '<li class="inline t-24 t-black t-normal break-words">\n            Noorjahan Shaily\n          </li>'

# %%
if name_2:
    n_name = name_2.strip()

# %%
name_2
# Out:
# '<li class="inline t-24 t-black t-normal break-words">\n            Noorjahan Shaily\n          </li>'

# %%
work = sel.css('h2.mt1.inline-block.t-18.t-black.t-normal').extract_first()

# %%
if work:
    work = work.strip()

# %%
work
# Out:
# '<h2 class="mt1 inline-block t-18 t-black t-normal">\n            Student at East West University\n          </h2>'

# %%
linkedin_urls[0]
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="8395e8811d76a31f7d494c56f3c28659", element="0.639072678325898-2")>

# %%
current_pos = driver.find_elements_by_css_selector('p.search-result__snippets.mt2.t-12.t-black--light.t-normal')

# %%
current_pos_txt = [ul.text for ul in current_pos]

# %%
current_pos_txt
# Out:
# []

# %%
driver.switch_to_window(driver.window_handles[0])
# Out:
# D:\Anaconda\Installation\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: use driver.switch_to.window instead
#   """Entry point for launching an IPython kernel.

# %%
current_pos = driver.find_elements_by_css_selector('p.search-result__snippets.mt2.t-12.t-black--light.t-normal')

# %%
linkedin_urls = driver.find_elements_by_css_selector('a.search-result__result-link.ember-view')

# %%
linkedin_urls[0]
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="8395e8811d76a31f7d494c56f3c28659", element="0.14607590947661508-1")>

# %%
linkedin_urls[0].get_attribute('innerHTML')
# Out:
# '      <figure class="search-result__image">\n          <div id="ember65" class="ivm-image-view-model ember-view">  <div id="ember66" class="display-flex ivm-view-attr__img-wrapper ivm-view-attr__img-wrapper--use-img-tag ember-view"><!---->    <div id="ember67" class="presence-entity presence-entity--size-4 ember-view"><img class="lazy-image ivm-view-attr__img--centered  EntityPhoto-circle-4 presence-entity__image EntityPhoto-circle-4 loaded" alt="Noorjahan Shaily" src="https://media.licdn.com/dms/image/C5103AQHdK-WWfOsORQ/profile-displayphoto-shrink_800_800/0?e=1565222400&amp;v=beta&amp;t=sXhMFr-eueFSVd5BFzIwbPenOB9-uLDl4zs-qdCao4c">\n\n<div id="ember68" class=" presence-entity__indicator presence-entity__indicator--size-4 presence-indicator presence-indicator--is-reachable presence-indicator--size-4 ember-view">\n<span class="visually-hidden">\n    Status is reachable\n</span>\n</div>\n</div>\n</div>\n</div>\n      </figure>\n'

# %%
linkedin_urls[0].get_attribute('href')
# Out:
# 'https://www.linkedin.com/in/noorjahan-shaily-a27a22127/'

# %%
linkedin_urls[1].get_attribute('href')
# Out:
# 'https://www.linkedin.com/in/noorjahan-shaily-a27a22127/'

# %%
linkedin_urls[2].get_attribute('href')
# Out:
# 'https://www.linkedin.com/in/khandaker-razzak-540114138/'

# %%
linkedin_urls[3].get_attribute('href')
# Out:
# 'https://www.linkedin.com/in/khandaker-razzak-540114138/'

# %%
linkedin_urls[4].get_attribute('href')
# Out:
# 'https://www.linkedin.com/in/kazi-md-farhad-mahmud-01a2b7b5/'

# %%
linkedin_urls[6].get_attribute('href')
# Out:
# 'https://www.linkedin.com/in/farhana-rahman-a5931315a/'

# %%
linkedin_urls[8].get_attribute('href')
# Out:
# 'https://www.linkedin.com/in/raz1tanvir/'

# %%
linkedin_urls = driver.find_elements_by_css_selector('a.search-result__result-link.ember-view')

# %%
linkedin_urls
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8395e8811d76a31f7d494c56f3c28659", element="0.14607590947661508-1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8395e8811d76a31f7d494c56f3c28659", element="0.14607590947661508-6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8395e8811d76a31f7d494c56f3c28659", element="0.14607590947661508-7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8395e8811d76a31f7d494c56f3c28659", element="0.14607590947661508-8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8395e8811d76a31f7d494c56f3c28659", element="0.14607590947661508-9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8395e8811d76a31f7d494c56f3c28659", element="0.14607590947661508-10")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8395e8811d76a31f7d494c56f3c28659", element="0.14607590947661508-11")>,
# ...

# %%
linkedin_urls[0].get_attribute('href')
# Out:
# 'https://www.linkedin.com/in/noorjahan-shaily-a27a22127/'

# %%
linkedin_urls[1].get_attribute('href')
# Out:
# 'https://www.linkedin.com/in/noorjahan-shaily-a27a22127/'

# %%
linkedin_urls[14].get_attribute('href')
# Out:
# 'https://www.linkedin.com/in/shantanurahut/'

# %%
linkedin_urls[18].get_attribute('href')
# Out:
# 'https://www.linkedin.com/in/afroja-mukta-74330a154/'

# %%
len(linkedin_urls)
# Out:
# 20

# %%
l = linkedin_urls[18].get_attribute('href')

# %%
driver.execute_script("window.open(arguments[0]);", l)

# %%
driver.switch_to.window(driver.window_handles[-1])

# %%
name_2 = sel.css('li.inline.t-24.t-black.t-normal.break-words').extract_first()

# %%
name_2
# Out:
# '<li class="inline t-24 t-black t-normal break-words">\n            Noorjahan Shaily\n          </li>'

# %%
deg_ree = driver.find_elements_by_css_selector('span.pv-entity__comma-item')

# %%
deg_ree = driver.find_elements_by_css_selector('span.pv-entity__comma-item')

# %%
deg_ree
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8395e8811d76a31f7d494c56f3c28659", element="0.5147988604626892-1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8395e8811d76a31f7d494c56f3c28659", element="0.5147988604626892-2")>]

# %%
deg_ree[0].get_attribute('outerHTML')
# Out:
# '<span class="pv-entity__comma-item">Bachelor of Business Administration - BBA</span>'

# %%
deg_ree[0].get_attribute('innerHTML')
# Out:
# 'Bachelor of Business Administration - BBA'

# %%
deg_ree[1].get_attribute('innerHTML')
# Out:
# 'Business Administration and Management, General'

# %%
work = sel.css('h2.mt1.inline-block.t-18.t-black.t-normal').extract_first()

# %%
work
# Out:
# '<h2 class="mt1 inline-block t-18 t-black t-normal">\n            Student at East West University\n          </h2>'
